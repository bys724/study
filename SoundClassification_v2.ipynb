# %%
import tensorflow as tf
import tensorflow_io as tfio
import matplotlib.pyplot as plt
from IPython.display import Audio

# %%
audio = tfio.audio.AudioIOTensor('test.mp3')
#print(audio)
print(audio[:10, 0])
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-3-fca76f636dd1> in <module>
# ----> 1 audio = tfio.audio.AudioIOTensor('test.mp3')
#       2 #print(audio)
#       3 print(audio[:10, 0])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_io/core/python/ops/audio_ops.py in __init__(self, filename, dtype)
#     234             if not tf.executing_eagerly():
#     235                 assert dtype is not None, "dtype must be provided in graph mode"
# --> 236             resource = core_ops.io_audio_readable_init(filename)
#     237             if tf.executing_eagerly():
#     238                 shape, dtype, rate = core_ops.io_audio_readable_spec(resource)
#
# <string> in io_audio_readable_init(input, container, shared_name, name)
#
# <string> in io_audio_readable_init_eager_fallback(input, container, shared_name, name, ctx)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# NotFoundError: test.mp3; No such file or directory [Op:IO>AudioReadableInit]

# %%
#audio = tfio.audio.AudioIOTensor('gs://cloud-samples-tests/speech/brooklyn.flac')
#print(audio.rate.numpy())
#audio_slice = tf.slice(audio)
"""
audio_slice = audio[100:]

audio_slice = audio[:,0]
print(audio_slice)

# remove last dimension
audio_tensor = tf.squeeze(audio_slice, axis=[-1])

print(audio_tensor)

"""
# Out:
# '\naudio_slice = audio[100:]\n\naudio_slice = audio[:,0]\nprint(audio_slice)\n\n# remove last dimension\naudio_tensor = tf.squeeze(audio_slice, axis=[-1])\n\nprint(audio_tensor)\n\n'

# %%
t = tf.constant([[[1, 1, 1], [2, 2, 2]],
                 [[3, 3, 3], [4, 4, 4]],
                 [[5, 5, 5], [6, 6, 6]]])
print(t.shape)
#print(t)
# Out:
# (3, 2, 3)

# %%
Audio(audio_tensor.numpy(), rate=audio.rate.numpy())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tensor = tf.cast(audio_tensor, tf.float32) / 32768.0

plt.figure()
plt.plot(tensor.numpy())

# %%
position = tfio.experimental.audio.trim(tensor, axis=0, epsilon=0.1)
print(position)

start = position[0]
stop = position[1]
print(start, stop)

processed = tensor[start:stop]

plt.figure()
plt.plot(processed.numpy())

Audio(processed.numpy(), rate=audio.rate.numpy())
# Out:
# tf.Tensor([ 2398 23546], shape=(2,), dtype=int64)
# tf.Tensor(2398, shape=(), dtype=int64) tf.Tensor(23546, shape=(), dtype=int64)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fade = tfio.experimental.audio.fade(
    processed, fade_in=1000, fade_out=2000, mode="logarithmic")

plt.figure()
plt.plot(fade.numpy())
Audio(fade.numpy(), rate=audio.rate.numpy())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
